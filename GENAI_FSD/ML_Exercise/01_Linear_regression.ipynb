# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Import data
df = pd.read_csv("Data/area_price_data.csv")

# %%
df.head()
# Out:
#    area_sqft   price
# 0       1360  194416
# 1       1794  265386
# 2       1630  222373
# 3       1595  215325
# 4       2138  336950

# %%
X = df.drop(['price'],axis=1).copy()

# %%
X
# Out:
#     area_sqft
# 0        1360
# 1        1794
# 2        1630
# 3        1595
# 4        2138
# ..        ...
# 95       2588
# 96       2682
# 97        700
# 98       2363
# 99       1279
#
# [100 rows x 1 columns]

# %%
y = df['price'].copy()

# %%
y
# Out:
# 0     194416
# 1     265386
# 2     222373
# 3     215325
# 4     336950
#        ...
# 95    373912
# 96    439615
# 97    114476
# 98    330623
# 99    204981
# Name: price, Length: 100, dtype: int64

# %%
plt.scatter(X,y)
plt.xlabel("Area")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((67, 1), (33, 1), (67,), (33,))

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_preds = reg.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train,y_preds)
# Out:
# 0.9697546045208387

# %%
## Predictions on Test Data

# %%
y_test_preds = reg.predict(X_test)

# %%
score = r2_score(y_test,y_test_preds)

# %%
score
# Out:
# 0.9688315641266687

# %%
X_test.shape, y_test.shape
# Out:
# ((33, 1), (33,))

# %%
# Plot Best Fit Line
plt.scatter(X_test, y_test)
plt.plot(X_test,y_test_preds)
plt.xlabel("Area (sqft)")
plt.ylabel("Price")
plt.title("Best Fit Line on Test Data")
plt.show()

# %%
reg.coef_
# Out:
# array([150.97466258])

# %%
reg.intercept_
# Out:
# -4297.1283826584695

# %%
X_test['area_sqft'][0]
# Out:
# 1360

# %% [markdown]
# y=mx+b
#
#
# y = m1*x1+m2*x2+m3*x3+b

# %%
150.97466258*1360+(-4297.1283826584695)
# Out:
# 201028.41272614154

# %%
reg.predict([[1360]])
# Out:
# C:\Users\Hexi\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([201028.41272211])
